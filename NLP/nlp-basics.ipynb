# %% [markdown]
# Natural Language Processing or NLP :

# %% [markdown]
# Text Classification
#
#
# - Loading Data
# - EDA
# - Data Preprocessing
#     - Cleaning the corpus
#     - Stemming
#     - All together
#     - Target Encoding
# - Token Visualization
# - Vectorization
#     - Tunning CountVectorizer
#     - TF-IDF
#     - Word embeddings: Glove
# - Modeling
#     - Naive Bayes DTM
#     - Naive Bayes TF-IDF
#     - XGBoost
# - LSTM
# - BERT
# - NLP : Disaster tweets
#     - EDA
#     - Data preprocessing
#     -
